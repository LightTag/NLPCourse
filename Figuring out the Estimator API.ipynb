# %% [markdown]
# # Goal
# This notebook is my live notes for figuring out how to use Tensorflows  Estimator API.
# I read the [official docs](https://www.tensorflow.org/guide/estimators) but they were a bit vauge for my taste, e.g. I couldn't read them and know what to do.
#
# For context, I have a toy problem, that has numbers as words in German and the actual words. I want to do two toy problems, one is classify whether a given word is even or odd. The other is convert from word to number using [NALU](https://arxiv.org/abs/1808.00508). It's 20:30 now and I have a baby that's switching between crying, feeding and sleeping. Let's see how far he lets us get.

# %% [markdown]
# # Step one - "Literature Review"
# The official docs point to a collection of [official models](https://github.com/tensorflow/models/tree/master/official) that are well maintained and serve as references for the high level APIs like Estimator. This is great. Even better, they have an implementation of the [Transformer model](https://github.com/tensorflow/models/tree/master/official/transformer) which is in the realm of NLP. That;s articulrly important because dataloading in NLP is a black art and getting it to play nice with a new API will be blacker than black so it's nice to have a reference to copy paste from
# ![funny](https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1457364208i/29437996._UY630_SR1200,630_.jpg)

# %% [markdown]
# ## A Caveat - The Transformer implementation is too good for me
# The implementation in the transormer model is a bit too good. It covers a lot of things I don't really need now like Bleu scores, running on TPUs and distributed training. Yes, these are highlights of the Estimator API but they are highlights I don't need now. So really the first thing I'll do is mark what I need to keep and delete

# %% [markdown]
# ## What we know
#
# So basically the Estimator API says "Give me a function that returns Data, and another function that returns a model, and I'll combine them, run them, calculate the metrics, save checkpoints, distribute it across nodes and make you coffee.
#
#
# So what we need to figure out is
# * How to write a model function
# * What are the specifications for the data function
#     * Can we use feed dicts or only TFRecords ?
#     * It looks like we need to seperate examples and labels for the API, where should we do that ?
#     * Can we preproccess the text in Python.

# %% [markdown]
# ## How to write a model function
# So the transformer model function is [here](https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L69)
# Notably, it's signature is
# ```python
# def model_fn(features, labels, mode, params):
#
# ```
# I guess features is inputs, labels is labels, I know that mode is one of [Train,Test,Predict] or something semantically equaivalent.
# If you look [here]((https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L81-L89) you'll see that the model returns something in the case that mode==PREDICT and then [here]((https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L125-L138) something else if mode==TRAIN.
#
# Cool. so first thing we know is that it should do different things based on mode. This is actually super duper awesome because before this their wasn't a canonical way to make that seperation and every project reinvented the wheel. So while a bit complex, it's great.
#
# ### What is the model_fn returning
# So when we look at what the model function is returing we see it returns an [EstimatorSpec](https://www.tensorflow.org/api_docs/python/tf/estimator/EstimatorSpec)
# ```python
#       return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
#
# ```
# Just looking at how it's called here this thing actually makes sense.
# The docs say
#
# >For mode == ModeKeys.TRAIN: required fields are loss and train_op.
#
# >For mode == ModeKeys.EVAL: required field is loss.
#
# >For mode == ModeKeys.PREDICT: required fields are predictions.
#
#
# So that tells us what the minumum we need to pass in. I wonder why we need to pass the loss into the estimator during training, since I assume it's implied in the training op that is minimizing the loss. But whatever.
#
# ### Where did loss and train_op come from ?
#
# So we saw in that little python snippet that we pass loss and train_op but where did they come from ?
# So in the begining of the model_fn they do
# ```python
#     model = transformer.Transformer(params, mode == tf.estimator.ModeKeys.TRAIN)
#
#     logits = model(inputs, targets)
# ```
# Where transformer is an import from some other directory.
# Then, once they've checked they are not in prediction mode, they calculate the loss
# ```python
#     xentropy, weights = metrics.padded_cross_entropy_loss(
#         logits, targets, params["label_smoothing"], params["vocab_size"])
#     loss = tf.reduce_sum(xentropy) / tf.reduce_sum(weights)
# ```
# Then they check if they are in eval or train mode, and if they are in train mode they also set up the train op
# ```python
#       train_op, metric_dict = get_train_op_and_metrics(loss, params)
# ```
# Where get_train_op_and_metrics is defined in the file.
#
# ### Two patterns emerge
# The first pattern to emerge is that they calculate only what is needed. Instead of saying calculate we can say they only set up the graph-ops that are needed. E.g. they don't make the train_op if they don't need it. I wonder if this is just good engineering or serves a more "practical purpose", e.g. to leave space on GPU or someething.
#
# Second pattern to emerge, which is **more important** is their use of imports and helper functions. Obviously this is a good pratice, and I mention it because i feel that when I copy and paste from X I'm not always confident about what "style" of programming I can use. This holds especially true in ML and frontend code where the software engineering chops vary wildly within the respective communities. But I digress

# %% [markdown]
# # Who calls the model_fn ?
# So we've seen that the model_fn they define returns an esitmator spec when it gets data and a mode. Who calls it the model_fn and where does it get the data from ?
# Well [here]((https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L499-L502) is an example. Let's copy paste it!
#
# ```python
#     return tf.estimator.Estimator(
#         model_fn=model_fn, model_dir=flags_obj.model_dir, params=params,
#         config=tf.estimator.RunConfig(train_distribute=distribution_strategy))
# ```
#
# Cool. So it makes sense that the Estimator class will call the model function, which will in turn return an estimator spec based on the mode. The thing is, model_fn is called with features and labels, where did they come from ? It's not obvious just from looking at this function. I can only assume that it's somehow specified in params. I vaugely remembered something about an input_fn so I searched the code for it and found
# [this morsel]((https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L334-L337)
# ```python
#     estimator.train(
#         dataset.train_input_fn,
#         steps=schedule_manager.single_iteration_train_steps,
#         hooks=train_hooks)
# ```
# And so, I realize that the estimator instance returned from instantiaing the Estimator class with our model_fn has a method on it called train that accepts an input function. Shoutout to timeless [Execution in the Kingdom of nouns](https://steve-yegge.blogspot.com/2006/03/execution-in-kingdom-of-nouns.html).
# It's actually very sensible, an instance of an estimator has a bunch of methods, like train, evaluate and predict, which happen to correspond to the things we'd like to do with a model. In any of these cases, we need to provide data to our model, which is done through an input_fn. We can do a bunch of extra fancy things which we'll get to later.

# %% [markdown]
# ## A question is answered! We now know the constraints on the data input
# We can now go look at the docs for the estimators [train](https://www.tensorflow.org/api_docs/python/tf/estimator/Estimator#train) method and see what we can pass around in the input_fn. To quote the docs
#
#         input_fn: A function that provides input data for training as minibatches. See Premade Estimators for more information. The function should construct and return one of the following:
#         * A tf.data.Dataset object: Outputs of Dataset object must be a tuple (features, labels) with same constraints as below.
#         * A tuple (features, labels): Where features is a tf.Tensor or a dictionary of string feature name to Tensor and labels is a Tensor or a dictionary of string label name to Tensor.
#         Both features and labels are consumed by model_fn. They should satisfy the expectation of model_fn from inputs.
#
# When we set out on this adventure I asked
# * Can we use feed dicts or only TFRecords ?
# * It looks like we need to seperate examples and labels for the API, where should we do that ?
# * Can we preproccess the text in Python.
#
# Let's answer them
#
# ### Can we use feed dicts or only TFRecords ?
# Apperently no way to use feeddicts. But, we don't need to use TFRecords, we just need a function that reads data on the fly and returns tensors.
# ### It looks like we need to seperate examples and labels for the API, where should we do that ?
# Well, input function says to return a Dataset object that returns a tuple. It isn't very specific about what that tuple should be.
#
# I'm not being nitpicky, I like to pass a lot of tensors in dictionaries, for example, I want to pass my examples in a tensor and another tensor with their lengths and put both of those in a dict. Apperently, I can, so long as I return a tuple of two dicts.
#
# I'll guestimate that the tensorflow folks were trying to avoid stuff like this when desiging the API. Probably the logic is that if you follow it to the letter you'll have super portable models that you can share and swap out parts. In my way, with the dicts, your model_fn now needs to parse dicts. Works for me.
#
# ### Can we preproccess the text in Python ?
# I think we can. We'll try to do that in a bit

# %% [markdown]
# # Setting up for Tensorboard
# Let's face it, the best part of doing deep learning is watching the loss go down on Tensorboard. While the estimator API promises to let us do that for free, we haven't seen how.
#
# So actually, in the Transformer example they have this cool function that gets a loss and some params and returns both the train ops and the metrics we want in tensorflow. It's [here](https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L166-L194). Basically they have a dict called metric_dict and it has names of scalars and scalrs. Then they run a function, [record_scalars](https://github.com/tensorflow/models/blob/master/official/transformer/transformer_main.py#L141) and that sets up the scalars for tensorboard.
#
# If you dig around, they do the same thing in slightly different ways, but really their is no magic here. You call tf.summary.X (or tf.contrib.summary.X)  and Estimator will take care of the rest. Amen

# %% [markdown]
# # Pre-Summary - Setting up some context
# As I mentioned, I have a toy task! It consists of taking a word in German that represents a number and predicting if it is even or odd. Conveniently, I have a program that gives me dicts whose keys are numbers and values are  their German word equivalent. Check it out (Disclaimer, I wrote this program and my German is shameful so maybe its wrong)

# %%
from utils.numtoWord import createNum2WordDict
createNum2WordDict(size=10,high=100)
# Out:
# {15: 'fünfzehn',
#  25: 'fünfundzwanzig',
#  30: 'unddreiβig',
#  38: 'achtunddreiβig',
#  43: 'dreiundvierzig',
#  48: 'achtundvierzig',
#  56: 'sechsundfünfzig',
#  57: 'siebenundfünfzig',
#  60: 'undsechzig',
#  62: 'zweiundsechzig'}

# %% [markdown]
# Cool!
# Now, let's see how we make that into something that maps Words to even numbers. (0 means odd, 1 means even)

# %%
d = createNum2WordDict(size=10,high=100)
d = {key: (val,(key+1)%2) for key,val in d.items()}
d
# Out:
# {0: ('', 1),
#  12: ('zwölf', 1),
#  20: ('undzwanzig', 1),
#  23: ('dreiundzwanzig', 0),
#  36: ('sechsunddreiβig', 1),
#  51: ('einundfünfzig', 0),
#  56: ('sechsundfünfzig', 1),
#  71: ('einundsiebzig', 0),
#  84: ('vierundachtzig', 1),
#  97: ('siebenundneunzig', 0)}

# %% [markdown]
# Cool, so now that I have my data here is what I want
# 1. A model that
#     * Is an LSTM
#     * Reads the words charechter by charechter
#     * Predicts if they are even or odd
# 2. An input function that
#     * calls my fancy function above and returns tensors in the proper format
# 3. An Estimarot that
#     * Uses my model via a model_fn and my input_fn to train and evaluate
#     * To see progress and accuracy in Tensorboard
#     * As a bonus, to do a one line deploy of this to Google-ml

# %% [markdown]
# # Summary
# So now I can summarize what I've learnt in light of what I want to do, e.g. derive a recipe.
# Basically
# 1. Find your data
# 2. Write a function that returns a Dataset object which in itself returns a tuple
# 3. Define your model somewhere, as a function that returns logits / predictions
# 4. Write a model_fn,
#     * Takes as input
#         * features and labels are the tuple from your input function
#         * mode is one of the values of [ModeKeys](https://www.tensorflow.org/api_docs/python/tf/estimator/ModeKeys)
#         * params are paramaters we haven't disucssed
#     * Returns an instance of an EstimatorSpec
#         * That does what needs to be done based on the mode (e.g. trains, or just predicts)
# 5. Instantiate an Estimator with the model_fn
# 6. Call estimator.train/eval/predict with the relevant input_fn
#
# It is now 22:07, so it took me an hour and forty to figure this out. My child did not interfere much so this was more or less continuous.
#
# Armed with this new knoweledge, I'm going to walk the dogs and then actually do this

# %%
import tensorflow as tf
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def nalu(input_layer, num_outputs):
    """ Neural Arithmetic Logic Unit tesnorflow layer
    Arguments:
    input_layer - A Tensor representing previous layer
    num_outputs - number of ouput units 
    Returns:
    A tensor representing the output of NALU
    """

    shape = (int(input_layer.shape[-1]), num_outputs)

    # define variables
    W_hat = tf.Variable(tf.truncated_normal(shape, stddev=0.02,dtype=tf.float64))
    M_hat = tf.Variable(tf.truncated_normal(shape, stddev=0.02,dtype=tf.float64))
    G = tf.Variable(tf.truncated_normal(shape, stddev=0.02,dtype=tf.float64))

    # operations according to paper
    W = tf.tanh(W_hat) * tf.sigmoid(M_hat)
    m = tf.exp(tf.matmul(tf.log(tf.abs(input_layer) + 1e-7), W))
    g = tf.sigmoid(tf.matmul(input_layer, G))
    a = tf.matmul(input_layer, W)
    out = g * a + (1 - g) * m

    return out

# %%
def model(inputs,labels,params):
    '''
        Inputs a dict of tensors {"sequences":[?,?],"lengths":[?]}
        labels a tesnor of shape [?] batch size
        returns logits [?] batch_size
    '''
    lengths = inputs["lengths"]
    sequences = inputs["sequences"]
    char_embeddings = tf.get_variable("char_embeddings",[params['vocab_size'], params['hidden_size']],dtype=tf.float64)
    embedded = tf.nn.embedding_lookup(char_embeddings, sequences)
    
    cell = tf.nn.rnn_cell.LSTMCell(num_units=params['hidden_size'],dtype=tf.float64)
    outputs, states = tf.nn.bidirectional_dynamic_rnn(cell,cell, embedded,sequence_length=lengths,
                                   dtype=tf.float64)
    state = tf.concat([states[0][0],states[1][0]],axis=1)
    logits = nalu(state,1)
    return tf.squeeze(logits)

# %%
from utils.numtoWord import createNum2WordDict, vocab
def generator_function(params):
    while True:
        d = createNum2WordDict(size=100,high=params['max_num'])
        for value,word in d.items():
            if value==0:
                continue
            ids = [vocab[char] for char in word]
            length = len(word)
            yield (ids,length,value )

# %%
def input_fn(params):
    generator = lambda : generator_function(params)
    dataset = tf.data.Dataset.from_generator(
        generator=generator,
        output_types=(tf.int64,tf.int64,tf.double),
        output_shapes=(tf.TensorShape([None]),tf.TensorShape([]),tf.TensorShape([]))
    )
    dataset =dataset.padded_batch(
    params['batch_size'],
    padded_shapes=(tf.TensorShape([None]),tf.TensorShape([]),tf.TensorShape([]))
    )
    
    dataset = dataset.map(lambda x,y,z: ({"sequences":x,"lengths":y},z))
    return dataset

# %% [markdown]
# # SIde hack, try the model out

# %%
# sess = tf.InteractiveSession()
# with tf.variable_scope("new18"):
#     ds =input_fn(params)
#     it = ds.make_one_shot_iterator()
#     next_el = it.get_next()
#     sess.run([tf.global_variables_initializer()])
#     logits = model(*next_el,params=params)
#     opt = tf.train.AdamOptimizer(0.001)
#     loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits,labels=next_el[1])
#     loss = tf.reduce_mean(loss)
#     train = opt.minimize(loss)
#     sess.run(tf.initialize_all_variables())

# %%
# for i in range(100):
#     _,l = sess.run([train,loss])
#     if i%50 ==0:
#         print(l)

# %% [markdown]
# # Back to making an estimator

# %%
def model_fn(features,labels,mode,params):
    with tf.variable_scope("model"):
        logits = model(features,labels,params)
        loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits,labels=labels)
        loss = tf.nn.l2_loss(logits - labels) # NALU uses mse

        loss = tf.reduce_mean(loss)
        tf.summary.scalar("loss",loss)
        opt = tf.train.AdamOptimizer(0.0001)
        train = opt.minimize(loss,global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train)

params = {
    "max_num":5000,
    "batch_size":32,
    "hidden_size":128,
    "vocab_size":len(vocab)
}


        
estimator = tf.estimator.Estimator(model_fn=model_fn,params=params)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpqhajrxkz
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_evaluation_master': '', '_task_id': 0, '_task_type': 'worker', '_global_id_in_cluster': 0, '_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_service': None, '_num_ps_replicas': 0, '_is_chief': True, '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f97153b3ac8>, '_train_distribute': None, '_master': '', '_model_dir': '/tmp/tmpqhajrxkz', '_tf_random_seed': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_device_fn': None}

# %%
estimator.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:417: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/deprecation.py:432: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:loss = 172930990.04924768, step = 1
# INFO:tensorflow:global_step/sec: 3.79334
# INFO:tensorflow:loss = 100603741.11380596, step = 101 (26.364 sec)
# INFO:tensorflow:global_step/sec: 4.17133
# INFO:tensorflow:loss = 44853105.048112184, step = 201 (23.973 sec)
# INFO:tensorflow:global_step/sec: 4.0366
# INFO:tensorflow:loss = 34108714.80213587, step = 301 (24.772 sec)
# INFO:tensorflow:global_step/sec: 3.74638
# INFO:tensorflow:loss = 24332296.444560308, step = 401 (26.695 sec)
# INFO:tensorflow:global_step/sec: 4.15361
# INFO:tensorflow:loss = 46854177.99624063, step = 501 (24.074 sec)
# INFO:tensorflow:global_step/sec: 4.1698
# INFO:tensorflow:loss = 50043140.43185718, step = 601 (23.982 sec)
# INFO:tensorflow:global_step/sec: 3.85865
# INFO:tensorflow:loss = 22354136.131035127, step = 701 (25.916 sec)
# INFO:tensorflow:global_step/sec: 4.56885
# INFO:tensorflow:loss = 17606494.089077517, step = 801 (21.887 sec)
# INFO:tensorflow:global_step/sec: 4.48873
# INFO:tensorflow:loss = 18719617.510852713, step = 901 (22.279 sec)
# INFO:tensorflow:global_step/sec: 4.45896
# INFO:tensorflow:loss = 38376292.10866053, step = 1001 (22.426 sec)
# INFO:tensorflow:global_step/sec: 4.5498
# INFO:tensorflow:loss = 29930190.655823, step = 1101 (21.979 sec)
# INFO:tensorflow:global_step/sec: 4.51618
# INFO:tensorflow:loss = 55187239.308123305, step = 1201 (22.142 sec)
# INFO:tensorflow:global_step/sec: 4.61544
# INFO:tensorflow:loss = 13855214.46224409, step = 1301 (21.667 sec)
# INFO:tensorflow:global_step/sec: 4.61144
# INFO:tensorflow:loss = 14266276.626659948, step = 1401 (21.686 sec)
# INFO:tensorflow:global_step/sec: 4.59
# INFO:tensorflow:loss = 33230135.27856242, step = 1501 (21.786 sec)
# INFO:tensorflow:global_step/sec: 4.55617
# INFO:tensorflow:loss = 8151037.299742192, step = 1601 (21.949 sec)
# INFO:tensorflow:global_step/sec: 4.45943
# INFO:tensorflow:loss = 15613705.434297297, step = 1701 (22.424 sec)
# INFO:tensorflow:global_step/sec: 4.55992
# INFO:tensorflow:loss = 10363853.254847638, step = 1801 (21.930 sec)
# INFO:tensorflow:global_step/sec: 4.61565
# INFO:tensorflow:loss = 12502612.358780768, step = 1901 (21.666 sec)
# INFO:tensorflow:global_step/sec: 4.53829
# INFO:tensorflow:loss = 11309614.026496183, step = 2001 (22.034 sec)
# INFO:tensorflow:global_step/sec: 4.53931
# INFO:tensorflow:loss = 17340921.601111453, step = 2101 (22.029 sec)
# INFO:tensorflow:global_step/sec: 4.46045
# INFO:tensorflow:loss = 19552799.606700465, step = 2201 (22.419 sec)
# INFO:tensorflow:global_step/sec: 4.58341
# INFO:tensorflow:loss = 9555675.778589629, step = 2301 (21.818 sec)
# INFO:tensorflow:global_step/sec: 4.5505
# INFO:tensorflow:loss = 11826577.367745232, step = 2401 (21.976 sec)
# INFO:tensorflow:global_step/sec: 4.53329
# INFO:tensorflow:loss = 11640309.601188298, step = 2501 (22.059 sec)
# INFO:tensorflow:global_step/sec: 4.50448
# INFO:tensorflow:loss = 30147425.22815756, step = 2601 (22.200 sec)
# INFO:tensorflow:Saving checkpoints for 2625 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.57061
# INFO:tensorflow:loss = 23852432.911428653, step = 2701 (21.879 sec)
# INFO:tensorflow:global_step/sec: 4.62153
# INFO:tensorflow:loss = 15650624.756458145, step = 2801 (21.639 sec)
# INFO:tensorflow:global_step/sec: 4.5694
# INFO:tensorflow:loss = 21474061.637861684, step = 2901 (21.884 sec)
# INFO:tensorflow:global_step/sec: 4.55024
# INFO:tensorflow:loss = 27424341.898430385, step = 3001 (21.981 sec)
# INFO:tensorflow:global_step/sec: 4.41863
# INFO:tensorflow:loss = 19814588.169094253, step = 3101 (22.628 sec)
# INFO:tensorflow:global_step/sec: 4.55682
# INFO:tensorflow:loss = 15825901.58198021, step = 3201 (21.945 sec)
# INFO:tensorflow:global_step/sec: 4.54172
# INFO:tensorflow:loss = 22770711.249290273, step = 3301 (22.020 sec)
# INFO:tensorflow:global_step/sec: 4.58822
# INFO:tensorflow:loss = 11031306.98776915, step = 3401 (21.793 sec)
# INFO:tensorflow:global_step/sec: 4.60169
# INFO:tensorflow:loss = 46636596.87747606, step = 3501 (21.731 sec)
# INFO:tensorflow:global_step/sec: 4.55018
# INFO:tensorflow:loss = 9889003.96112102, step = 3601 (21.977 sec)
# INFO:tensorflow:global_step/sec: 4.51969
# INFO:tensorflow:loss = 16866114.35832654, step = 3701 (22.127 sec)
# INFO:tensorflow:global_step/sec: 4.47705
# INFO:tensorflow:loss = 24980867.931506258, step = 3801 (22.334 sec)
# INFO:tensorflow:global_step/sec: 4.47385
# INFO:tensorflow:loss = 17169911.581908632, step = 3901 (22.352 sec)
# INFO:tensorflow:global_step/sec: 4.56532
# INFO:tensorflow:loss = 22915385.596338205, step = 4001 (21.904 sec)
# INFO:tensorflow:global_step/sec: 4.51529
# INFO:tensorflow:loss = 24292271.385917947, step = 4101 (22.147 sec)
# INFO:tensorflow:global_step/sec: 4.5252
# INFO:tensorflow:loss = 27199108.692404307, step = 4201 (22.098 sec)
# INFO:tensorflow:global_step/sec: 4.57837
# INFO:tensorflow:loss = 13168997.655066036, step = 4301 (21.842 sec)
# INFO:tensorflow:global_step/sec: 4.51828
# INFO:tensorflow:loss = 37203057.464156345, step = 4401 (22.132 sec)
# INFO:tensorflow:global_step/sec: 4.47164
# INFO:tensorflow:loss = 19939078.229350828, step = 4501 (22.363 sec)
# INFO:tensorflow:global_step/sec: 4.61947
# INFO:tensorflow:loss = 13973182.648474075, step = 4601 (21.647 sec)
# INFO:tensorflow:global_step/sec: 4.52979
# INFO:tensorflow:loss = 17639721.458023593, step = 4701 (22.076 sec)
# INFO:tensorflow:global_step/sec: 4.44474
# INFO:tensorflow:loss = 14474955.708910337, step = 4801 (22.498 sec)
# INFO:tensorflow:global_step/sec: 4.46766
# INFO:tensorflow:loss = 8380590.0732381055, step = 4901 (22.383 sec)
# INFO:tensorflow:global_step/sec: 4.48521
# INFO:tensorflow:loss = 78719751.76835872, step = 5001 (22.295 sec)
# INFO:tensorflow:global_step/sec: 4.44766
# INFO:tensorflow:loss = 24237938.03006552, step = 5101 (22.486 sec)
# INFO:tensorflow:global_step/sec: 4.51887
# INFO:tensorflow:loss = 15962055.31458116, step = 5201 (22.127 sec)
# INFO:tensorflow:global_step/sec: 4.47539
# INFO:tensorflow:loss = 14258587.902977174, step = 5301 (22.353 sec)
# INFO:tensorflow:Saving checkpoints for 5341 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.57869
# INFO:tensorflow:loss = 18466296.52003268, step = 5401 (21.831 sec)
# INFO:tensorflow:global_step/sec: 4.49404
# INFO:tensorflow:loss = 24761950.382664304, step = 5501 (22.253 sec)
# INFO:tensorflow:global_step/sec: 4.542
# INFO:tensorflow:loss = 17365272.27856677, step = 5601 (22.016 sec)
# INFO:tensorflow:global_step/sec: 4.53033
# INFO:tensorflow:loss = 32196431.50089934, step = 5701 (22.074 sec)
# INFO:tensorflow:global_step/sec: 4.47768
# INFO:tensorflow:loss = 30159935.18819383, step = 5801 (22.332 sec)
# INFO:tensorflow:global_step/sec: 4.45758
# INFO:tensorflow:loss = 22110496.831393447, step = 5901 (22.434 sec)
# INFO:tensorflow:global_step/sec: 4.54342
# INFO:tensorflow:loss = 19399783.30976552, step = 6001 (22.009 sec)
# INFO:tensorflow:global_step/sec: 4.51969
# INFO:tensorflow:loss = 20048494.453320935, step = 6101 (22.126 sec)
# INFO:tensorflow:global_step/sec: 4.4848
# INFO:tensorflow:loss = 12168887.685444813, step = 6201 (22.297 sec)
# INFO:tensorflow:global_step/sec: 4.47848
# INFO:tensorflow:loss = 31541414.373544276, step = 6301 (22.329 sec)
# INFO:tensorflow:global_step/sec: 4.50409
# INFO:tensorflow:loss = 15441778.75136238, step = 6401 (22.202 sec)
# INFO:tensorflow:global_step/sec: 4.53546
# INFO:tensorflow:loss = 16061244.589664394, step = 6501 (22.048 sec)
# INFO:tensorflow:global_step/sec: 4.48626
# INFO:tensorflow:loss = 18035358.66029378, step = 6601 (22.290 sec)
# INFO:tensorflow:global_step/sec: 4.53726
# INFO:tensorflow:loss = 19765387.89220039, step = 6701 (22.040 sec)
# INFO:tensorflow:global_step/sec: 4.46528
# INFO:tensorflow:loss = 22984159.44177398, step = 6801 (22.395 sec)
# INFO:tensorflow:global_step/sec: 4.54287
# INFO:tensorflow:loss = 20130895.669376504, step = 6901 (22.012 sec)
# INFO:tensorflow:global_step/sec: 4.48387
# INFO:tensorflow:loss = 10070395.73918238, step = 7001 (22.302 sec)
# INFO:tensorflow:global_step/sec: 4.46667
# INFO:tensorflow:loss = 14000603.525941122, step = 7101 (22.388 sec)
# INFO:tensorflow:global_step/sec: 4.5181
# INFO:tensorflow:loss = 10057452.830848247, step = 7201 (22.133 sec)
# INFO:tensorflow:global_step/sec: 4.55668
# INFO:tensorflow:loss = 11473754.58756508, step = 7301 (21.946 sec)
# INFO:tensorflow:global_step/sec: 4.48553
# INFO:tensorflow:loss = 16430049.930695642, step = 7401 (22.294 sec)
# INFO:tensorflow:global_step/sec: 4.37824
# INFO:tensorflow:loss = 6135609.415338006, step = 7501 (22.840 sec)
# INFO:tensorflow:global_step/sec: 4.53868
# INFO:tensorflow:loss = 7226764.341341699, step = 7601 (22.034 sec)
# INFO:tensorflow:global_step/sec: 4.48571
# INFO:tensorflow:loss = 16566288.024655823, step = 7701 (22.297 sec)
# INFO:tensorflow:global_step/sec: 4.523
# INFO:tensorflow:loss = 14273362.020352492, step = 7801 (22.104 sec)
# INFO:tensorflow:global_step/sec: 4.5984
# INFO:tensorflow:loss = 15977603.855547713, step = 7901 (21.747 sec)
# INFO:tensorflow:global_step/sec: 4.53666
# INFO:tensorflow:loss = 15933507.85192395, step = 8001 (22.043 sec)
# INFO:tensorflow:Saving checkpoints for 8047 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.49501
# INFO:tensorflow:loss = 12533363.989597654, step = 8101 (22.247 sec)
# INFO:tensorflow:global_step/sec: 4.57866
# INFO:tensorflow:loss = 8018343.789483354, step = 8201 (21.840 sec)
# INFO:tensorflow:global_step/sec: 4.56563
# INFO:tensorflow:loss = 8663555.438825142, step = 8301 (21.903 sec)
# INFO:tensorflow:global_step/sec: 4.68052
# INFO:tensorflow:loss = 8096895.728077109, step = 8401 (21.367 sec)
# INFO:tensorflow:global_step/sec: 4.32743
# INFO:tensorflow:loss = 5248677.374678466, step = 8501 (23.107 sec)
# INFO:tensorflow:global_step/sec: 4.48642
# INFO:tensorflow:loss = 11516594.339137385, step = 8601 (22.289 sec)
# INFO:tensorflow:global_step/sec: 4.54869
# INFO:tensorflow:loss = 8006265.772037081, step = 8701 (21.985 sec)
# INFO:tensorflow:global_step/sec: 4.5152
# INFO:tensorflow:loss = 16717316.780716397, step = 8801 (22.147 sec)
# INFO:tensorflow:global_step/sec: 4.51383
# INFO:tensorflow:loss = 14609314.19664028, step = 8901 (22.154 sec)
# INFO:tensorflow:global_step/sec: 4.54406
# INFO:tensorflow:loss = 12208821.107195098, step = 9001 (22.007 sec)
# INFO:tensorflow:global_step/sec: 4.57508
# INFO:tensorflow:loss = 20944759.588095132, step = 9101 (21.857 sec)
# INFO:tensorflow:global_step/sec: 4.46808
# INFO:tensorflow:loss = 8412656.957813546, step = 9201 (22.383 sec)
# INFO:tensorflow:global_step/sec: 4.52901
# INFO:tensorflow:loss = 10023039.546029033, step = 9301 (22.078 sec)
# INFO:tensorflow:global_step/sec: 4.42967
# INFO:tensorflow:loss = 20781547.598074228, step = 9401 (22.575 sec)
# INFO:tensorflow:global_step/sec: 4.97969
# INFO:tensorflow:loss = 13395895.768588133, step = 9501 (20.081 sec)
# INFO:tensorflow:global_step/sec: 5.07975
# INFO:tensorflow:loss = 15060246.992026508, step = 9601 (19.686 sec)
# INFO:tensorflow:global_step/sec: 5.06301
# INFO:tensorflow:loss = 21423483.9874577, step = 9701 (19.751 sec)
# INFO:tensorflow:global_step/sec: 5.07614
# INFO:tensorflow:loss = 10814279.60756243, step = 9801 (19.700 sec)
# INFO:tensorflow:global_step/sec: 5.0473
# INFO:tensorflow:loss = 14022156.277492382, step = 9901 (19.813 sec)
# INFO:tensorflow:global_step/sec: 5.01551
# INFO:tensorflow:loss = 18308456.23090383, step = 10001 (19.938 sec)
# INFO:tensorflow:global_step/sec: 5.03498
# INFO:tensorflow:loss = 19312663.850157976, step = 10101 (19.861 sec)
# INFO:tensorflow:global_step/sec: 5.08659
# INFO:tensorflow:loss = 11736480.907426424, step = 10201 (19.660 sec)
# INFO:tensorflow:global_step/sec: 5.08551
# INFO:tensorflow:loss = 20560623.644738562, step = 10301 (19.664 sec)
# INFO:tensorflow:global_step/sec: 5.06784
# INFO:tensorflow:loss = 12712245.042221986, step = 10401 (19.732 sec)
# INFO:tensorflow:global_step/sec: 5.08126
# INFO:tensorflow:loss = 16480970.940597946, step = 10501 (19.680 sec)
# INFO:tensorflow:global_step/sec: 5.05309
# INFO:tensorflow:loss = 53046077.55536911, step = 10601 (19.790 sec)
# INFO:tensorflow:global_step/sec: 5.04486
# INFO:tensorflow:loss = 19112376.268437654, step = 10701 (19.822 sec)
# INFO:tensorflow:global_step/sec: 5.06333
# INFO:tensorflow:loss = 18084180.781262208, step = 10801 (19.750 sec)
# INFO:tensorflow:global_step/sec: 5.0652
# INFO:tensorflow:loss = 14829745.780039674, step = 10901 (19.742 sec)
# INFO:tensorflow:Saving checkpoints for 10919 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 5.02699
# INFO:tensorflow:loss = 12980925.966392, step = 11001 (19.893 sec)
# INFO:tensorflow:global_step/sec: 5.06684
# INFO:tensorflow:loss = 29439917.18523053, step = 11101 (19.736 sec)
# INFO:tensorflow:global_step/sec: 5.0844
# INFO:tensorflow:loss = 18908712.09572625, step = 11201 (19.668 sec)
# INFO:tensorflow:global_step/sec: 5.04795
# INFO:tensorflow:loss = 21965905.99307288, step = 11301 (19.810 sec)
# INFO:tensorflow:global_step/sec: 5.04163
# INFO:tensorflow:loss = 15565057.496033657, step = 11401 (19.835 sec)
# INFO:tensorflow:global_step/sec: 5.05609
# INFO:tensorflow:loss = 66131536.341150716, step = 11501 (19.778 sec)
# INFO:tensorflow:global_step/sec: 5.01896
# INFO:tensorflow:loss = 20289914.77411354, step = 11601 (19.925 sec)
# INFO:tensorflow:global_step/sec: 5.05722
# INFO:tensorflow:loss = 18579851.69755587, step = 11701 (19.774 sec)
# INFO:tensorflow:global_step/sec: 5.06012
# INFO:tensorflow:loss = 23818629.86057458, step = 11801 (19.762 sec)
# INFO:tensorflow:global_step/sec: 5.02294
# INFO:tensorflow:loss = 18464097.569423, step = 11901 (19.909 sec)
# INFO:tensorflow:global_step/sec: 5.04512
# INFO:tensorflow:loss = 9382217.187738866, step = 12001 (19.821 sec)
# INFO:tensorflow:global_step/sec: 5.07456
# INFO:tensorflow:loss = 19621593.638259485, step = 12101 (19.706 sec)
# INFO:tensorflow:global_step/sec: 5.02588
# INFO:tensorflow:loss = 5850903.0051174015, step = 12201 (19.897 sec)
# INFO:tensorflow:global_step/sec: 5.05928
# INFO:tensorflow:loss = 8301348.389414785, step = 12301 (19.766 sec)
# INFO:tensorflow:global_step/sec: 5.06254
# INFO:tensorflow:loss = 35530682.933493465, step = 12401 (19.753 sec)
# INFO:tensorflow:global_step/sec: 5.0088
# INFO:tensorflow:loss = 34061076.32715286, step = 12501 (19.965 sec)
# INFO:tensorflow:global_step/sec: 5.06815
# INFO:tensorflow:loss = 27408337.771725602, step = 12601 (19.731 sec)
# INFO:tensorflow:global_step/sec: 5.00583
# INFO:tensorflow:loss = 31375984.70797647, step = 12701 (19.977 sec)
# INFO:tensorflow:global_step/sec: 5.03614
# INFO:tensorflow:loss = 37116090.697409324, step = 12801 (19.857 sec)
# INFO:tensorflow:global_step/sec: 5.01932
# INFO:tensorflow:loss = 22467893.34466817, step = 12901 (19.923 sec)
# INFO:tensorflow:global_step/sec: 5.0292
# INFO:tensorflow:loss = 23310230.81979147, step = 13001 (19.884 sec)
# INFO:tensorflow:global_step/sec: 5.01545
# INFO:tensorflow:loss = 21620483.993226733, step = 13101 (19.938 sec)
# INFO:tensorflow:global_step/sec: 5.06191
# INFO:tensorflow:loss = 16941540.1608953, step = 13201 (19.755 sec)
# INFO:tensorflow:global_step/sec: 5.05155
# INFO:tensorflow:loss = 14112492.86022722, step = 13301 (19.796 sec)
# INFO:tensorflow:global_step/sec: 5.04535
# INFO:tensorflow:loss = 14594993.147014506, step = 13401 (19.820 sec)
# INFO:tensorflow:global_step/sec: 5.05931
# INFO:tensorflow:loss = 21092892.36655048, step = 13501 (19.765 sec)
# INFO:tensorflow:global_step/sec: 5.07
# INFO:tensorflow:loss = 13695377.677634258, step = 13601 (19.724 sec)
# INFO:tensorflow:global_step/sec: 5.01016
# INFO:tensorflow:loss = 12687533.649605617, step = 13701 (19.960 sec)
# INFO:tensorflow:global_step/sec: 5.05245
# INFO:tensorflow:loss = 20660165.040268376, step = 13801 (19.792 sec)
# INFO:tensorflow:global_step/sec: 5.05417
# INFO:tensorflow:loss = 28932879.76327257, step = 13901 (19.786 sec)
# INFO:tensorflow:Saving checkpoints for 13946 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.9764
# INFO:tensorflow:loss = 13707426.255418804, step = 14001 (20.095 sec)
# INFO:tensorflow:global_step/sec: 5.05927
# INFO:tensorflow:loss = 16972811.071351968, step = 14101 (19.766 sec)
# INFO:tensorflow:global_step/sec: 5.0693
# INFO:tensorflow:loss = 10454342.111710288, step = 14201 (19.727 sec)
# INFO:tensorflow:global_step/sec: 5.00603
# INFO:tensorflow:loss = 6456774.617390536, step = 14301 (19.976 sec)
# INFO:tensorflow:global_step/sec: 5.02339
# INFO:tensorflow:loss = 14397656.943593943, step = 14401 (19.908 sec)
# INFO:tensorflow:global_step/sec: 5.01361
# INFO:tensorflow:loss = 35017580.18803251, step = 14501 (19.944 sec)
# INFO:tensorflow:global_step/sec: 5.01672
# INFO:tensorflow:loss = 23448378.989832655, step = 14601 (19.934 sec)
# INFO:tensorflow:global_step/sec: 5.04376
# INFO:tensorflow:loss = 18182696.682309024, step = 14701 (19.827 sec)
# INFO:tensorflow:global_step/sec: 5.00765
# INFO:tensorflow:loss = 13432733.762523215, step = 14801 (19.969 sec)
# INFO:tensorflow:global_step/sec: 5.00405
# INFO:tensorflow:loss = 17458158.648904458, step = 14901 (19.984 sec)
# INFO:tensorflow:global_step/sec: 5.01891
# INFO:tensorflow:loss = 11587110.240572358, step = 15001 (19.925 sec)
# INFO:tensorflow:global_step/sec: 5.04465
# INFO:tensorflow:loss = 8113668.316901936, step = 15101 (19.823 sec)
# INFO:tensorflow:global_step/sec: 5.02544
# INFO:tensorflow:loss = 22176612.329048295, step = 15201 (19.899 sec)
# INFO:tensorflow:global_step/sec: 5.04315
# INFO:tensorflow:loss = 22437273.0532052, step = 15301 (19.829 sec)
# INFO:tensorflow:global_step/sec: 5.06919
# INFO:tensorflow:loss = 11891727.245329868, step = 15401 (19.727 sec)
# INFO:tensorflow:global_step/sec: 5.03066
# INFO:tensorflow:loss = 18526097.67369102, step = 15501 (19.878 sec)
# INFO:tensorflow:global_step/sec: 5.0466
# INFO:tensorflow:loss = 8066551.531394761, step = 15601 (19.815 sec)
# INFO:tensorflow:global_step/sec: 5.04996
# INFO:tensorflow:loss = 14180614.736349005, step = 15701 (19.802 sec)
# INFO:tensorflow:global_step/sec: 5.03174
# INFO:tensorflow:loss = 10142801.252690848, step = 15801 (19.874 sec)
# INFO:tensorflow:global_step/sec: 5.01447
# INFO:tensorflow:loss = 12657591.193780435, step = 15901 (19.942 sec)
# INFO:tensorflow:global_step/sec: 5.04254
# INFO:tensorflow:loss = 12397779.007583015, step = 16001 (19.831 sec)
# INFO:tensorflow:global_step/sec: 4.99563
# INFO:tensorflow:loss = 14966309.859141147, step = 16101 (20.017 sec)
# INFO:tensorflow:global_step/sec: 5.05445
# INFO:tensorflow:loss = 8673908.69330551, step = 16201 (19.785 sec)
# INFO:tensorflow:global_step/sec: 5.04648
# INFO:tensorflow:loss = 10473491.387319611, step = 16301 (19.816 sec)
# INFO:tensorflow:global_step/sec: 4.99565
# INFO:tensorflow:loss = 9010131.783091225, step = 16401 (20.017 sec)
# INFO:tensorflow:global_step/sec: 5.04816
# INFO:tensorflow:loss = 5740143.879928816, step = 16501 (19.809 sec)
# INFO:tensorflow:global_step/sec: 5.07477
# INFO:tensorflow:loss = 9679176.364425372, step = 16601 (19.705 sec)
# INFO:tensorflow:global_step/sec: 4.93292
# INFO:tensorflow:loss = 7328272.023694206, step = 16701 (20.272 sec)
# INFO:tensorflow:global_step/sec: 5.06611
# INFO:tensorflow:loss = 6811317.751044741, step = 16801 (19.739 sec)
# INFO:tensorflow:global_step/sec: 4.98836
# INFO:tensorflow:loss = 6242745.164530663, step = 16901 (20.047 sec)
# INFO:tensorflow:Saving checkpoints for 16964 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.99595
# INFO:tensorflow:loss = 7774780.404795557, step = 17001 (20.016 sec)
# INFO:tensorflow:global_step/sec: 5.09609
# INFO:tensorflow:loss = 7538321.445140379, step = 17101 (19.623 sec)
# INFO:tensorflow:global_step/sec: 5.06527
# INFO:tensorflow:loss = 6703192.726765618, step = 17201 (19.742 sec)
# INFO:tensorflow:global_step/sec: 5.01031
# INFO:tensorflow:loss = 5666221.892039357, step = 17301 (19.959 sec)
# INFO:tensorflow:global_step/sec: 5.03776
# INFO:tensorflow:loss = 6003836.826837538, step = 17401 (19.850 sec)
# INFO:tensorflow:global_step/sec: 5.02486
# INFO:tensorflow:loss = 5892563.274851305, step = 17501 (19.901 sec)
# INFO:tensorflow:global_step/sec: 5.02984
# INFO:tensorflow:loss = 7800522.189617657, step = 17601 (19.881 sec)
# INFO:tensorflow:global_step/sec: 5.0375
# INFO:tensorflow:loss = 2463180.1945735943, step = 17701 (19.851 sec)
# INFO:tensorflow:global_step/sec: 5.05636
# INFO:tensorflow:loss = 8323726.5753433, step = 17801 (19.777 sec)
# INFO:tensorflow:global_step/sec: 5.01249
# INFO:tensorflow:loss = 6129483.488335814, step = 17901 (19.950 sec)
# INFO:tensorflow:global_step/sec: 5.05755
# INFO:tensorflow:loss = 6925240.886359429, step = 18001 (19.772 sec)
# INFO:tensorflow:global_step/sec: 5.04992
# INFO:tensorflow:loss = 19516679.761271305, step = 18101 (19.802 sec)
# INFO:tensorflow:global_step/sec: 5.0042
# INFO:tensorflow:loss = 16343078.991329104, step = 18201 (19.983 sec)
# INFO:tensorflow:global_step/sec: 5.06783
# INFO:tensorflow:loss = 5406294.207300462, step = 18301 (19.732 sec)
# INFO:tensorflow:global_step/sec: 5.06306
# INFO:tensorflow:loss = 3700068.597100504, step = 18401 (19.751 sec)
# INFO:tensorflow:global_step/sec: 5.02468
# INFO:tensorflow:loss = 6781263.031344573, step = 18501 (19.905 sec)
# INFO:tensorflow:global_step/sec: 5.03188
# INFO:tensorflow:loss = 12345081.298012495, step = 18601 (19.870 sec)
# INFO:tensorflow:global_step/sec: 5.04257
# INFO:tensorflow:loss = 3113335.2889473736, step = 18701 (19.831 sec)
# INFO:tensorflow:global_step/sec: 5.04131
# INFO:tensorflow:loss = 9809238.59700939, step = 18801 (19.836 sec)
# INFO:tensorflow:global_step/sec: 5.05651
# INFO:tensorflow:loss = 7700351.153953986, step = 18901 (19.777 sec)
# INFO:tensorflow:global_step/sec: 5.0021
# INFO:tensorflow:loss = 5763166.957104106, step = 19001 (19.992 sec)
# INFO:tensorflow:global_step/sec: 5.00447
# INFO:tensorflow:loss = 8672091.26139341, step = 19101 (19.982 sec)
# INFO:tensorflow:global_step/sec: 4.98553
# INFO:tensorflow:loss = 5227438.178203035, step = 19201 (20.058 sec)
# INFO:tensorflow:global_step/sec: 5.04682
# INFO:tensorflow:loss = 5552045.043221943, step = 19301 (19.814 sec)
# INFO:tensorflow:global_step/sec: 5.03012
# INFO:tensorflow:loss = 5539024.82890377, step = 19401 (19.880 sec)
# INFO:tensorflow:global_step/sec: 5.04811
# INFO:tensorflow:loss = 3778589.3893864416, step = 19501 (19.809 sec)
# INFO:tensorflow:global_step/sec: 5.04732
# INFO:tensorflow:loss = 2188091.1988623673, step = 19601 (19.812 sec)
# INFO:tensorflow:global_step/sec: 5.07003
# INFO:tensorflow:loss = 2867114.2288302, step = 19701 (19.724 sec)
# INFO:tensorflow:global_step/sec: 5.00633
# INFO:tensorflow:loss = 4875932.044686055, step = 19801 (19.975 sec)
# INFO:tensorflow:global_step/sec: 5.04517
# INFO:tensorflow:loss = 3271143.406775977, step = 19901 (19.821 sec)
# INFO:tensorflow:Saving checkpoints for 19986 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.97152
# INFO:tensorflow:loss = 2419972.212070421, step = 20001 (20.115 sec)
# INFO:tensorflow:global_step/sec: 5.04631
# INFO:tensorflow:loss = 4554198.25747245, step = 20101 (19.816 sec)
# INFO:tensorflow:global_step/sec: 5.04986
# INFO:tensorflow:loss = 5786788.166578255, step = 20201 (19.803 sec)
# INFO:tensorflow:global_step/sec: 5.0408
# INFO:tensorflow:loss = 9687207.510343222, step = 20301 (19.838 sec)
# INFO:tensorflow:global_step/sec: 5.00443
# INFO:tensorflow:loss = 3410433.493324532, step = 20401 (19.983 sec)
# INFO:tensorflow:global_step/sec: 4.98697
# INFO:tensorflow:loss = 3384783.1475904286, step = 20501 (20.052 sec)
# INFO:tensorflow:global_step/sec: 5.01021
# INFO:tensorflow:loss = 3583575.714046775, step = 20601 (19.959 sec)
# INFO:tensorflow:global_step/sec: 5.03276
# INFO:tensorflow:loss = 2252331.863321198, step = 20701 (19.870 sec)
# INFO:tensorflow:global_step/sec: 5.04944
# INFO:tensorflow:loss = 4837723.555320655, step = 20801 (19.804 sec)
# INFO:tensorflow:global_step/sec: 5.06152
# INFO:tensorflow:loss = 4261549.874618882, step = 20901 (19.757 sec)
# INFO:tensorflow:global_step/sec: 5.00802
# INFO:tensorflow:loss = 1740666.9878952461, step = 21001 (19.968 sec)
# INFO:tensorflow:global_step/sec: 5.07813
# INFO:tensorflow:loss = 7109361.292225427, step = 21101 (19.692 sec)
# INFO:tensorflow:global_step/sec: 5.0188
# INFO:tensorflow:loss = 3251684.9943981743, step = 21201 (19.925 sec)
# INFO:tensorflow:global_step/sec: 5.06262
# INFO:tensorflow:loss = 2739261.214850111, step = 21301 (19.753 sec)
# INFO:tensorflow:global_step/sec: 5.02971
# INFO:tensorflow:loss = 3121797.2799081393, step = 21401 (19.882 sec)
# INFO:tensorflow:global_step/sec: 5.03607
# INFO:tensorflow:loss = 1212325.0360055522, step = 21501 (19.857 sec)
# INFO:tensorflow:global_step/sec: 5.01061
# INFO:tensorflow:loss = 4730989.052578319, step = 21601 (19.958 sec)
# INFO:tensorflow:global_step/sec: 5.05824
# INFO:tensorflow:loss = 4877788.169050291, step = 21701 (19.770 sec)
# INFO:tensorflow:global_step/sec: 5.05989
# INFO:tensorflow:loss = 4086675.24030818, step = 21801 (19.763 sec)
# INFO:tensorflow:global_step/sec: 5.04925
# INFO:tensorflow:loss = 4738457.444300904, step = 21901 (19.805 sec)
# INFO:tensorflow:global_step/sec: 5.00312
# INFO:tensorflow:loss = 2122916.587268344, step = 22001 (19.988 sec)
# INFO:tensorflow:global_step/sec: 5.05435
# INFO:tensorflow:loss = 2929984.915270215, step = 22101 (19.785 sec)
# INFO:tensorflow:global_step/sec: 5.02353
# INFO:tensorflow:loss = 1229636.0015456167, step = 22201 (19.906 sec)
# INFO:tensorflow:global_step/sec: 5.04913
# INFO:tensorflow:loss = 1576427.3093946315, step = 22301 (19.806 sec)
# INFO:tensorflow:global_step/sec: 5.00411
# INFO:tensorflow:loss = 4394575.185366991, step = 22401 (19.984 sec)
# INFO:tensorflow:global_step/sec: 5.05225
# INFO:tensorflow:loss = 3328830.9241111544, step = 22501 (19.793 sec)
# INFO:tensorflow:global_step/sec: 5.05217
# INFO:tensorflow:loss = 5154891.896791347, step = 22601 (19.794 sec)
# INFO:tensorflow:global_step/sec: 5.06194
# INFO:tensorflow:loss = 2452074.5100208526, step = 22701 (19.755 sec)
# INFO:tensorflow:global_step/sec: 5.01888
# INFO:tensorflow:loss = 2097005.9239440227, step = 22801 (19.925 sec)
# INFO:tensorflow:global_step/sec: 5.04796
# INFO:tensorflow:loss = 4716975.335407359, step = 22901 (19.810 sec)
# INFO:tensorflow:global_step/sec: 5.02217
# INFO:tensorflow:loss = 4830383.17066761, step = 23001 (19.912 sec)
# INFO:tensorflow:Saving checkpoints for 23007 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 5.0072
# INFO:tensorflow:loss = 2624243.659677069, step = 23101 (19.971 sec)
# INFO:tensorflow:global_step/sec: 5.03604
# INFO:tensorflow:loss = 4973443.484394608, step = 23201 (19.857 sec)
# INFO:tensorflow:global_step/sec: 4.94138
# INFO:tensorflow:loss = 1817910.0808754482, step = 23301 (20.237 sec)
# INFO:tensorflow:global_step/sec: 5.18583
# INFO:tensorflow:loss = 3548118.318605775, step = 23401 (19.285 sec)
# INFO:tensorflow:global_step/sec: 4.98212
# INFO:tensorflow:loss = 3887730.233139229, step = 23501 (20.070 sec)
# INFO:tensorflow:global_step/sec: 4.79411
# INFO:tensorflow:loss = 3566413.319962613, step = 23601 (20.859 sec)
# INFO:tensorflow:global_step/sec: 4.42851
# INFO:tensorflow:loss = 2338294.912094539, step = 23701 (22.582 sec)
# INFO:tensorflow:global_step/sec: 4.27245
# INFO:tensorflow:loss = 5719074.203313289, step = 23801 (23.405 sec)
# INFO:tensorflow:global_step/sec: 4.41464
# INFO:tensorflow:loss = 3134537.932530163, step = 23901 (22.652 sec)
# INFO:tensorflow:global_step/sec: 3.82623
# INFO:tensorflow:loss = 1393232.2156779808, step = 24001 (26.136 sec)
# INFO:tensorflow:global_step/sec: 4.19564
# INFO:tensorflow:loss = 2963478.715548381, step = 24101 (23.833 sec)
# INFO:tensorflow:global_step/sec: 4.48183
# INFO:tensorflow:loss = 2981611.159000855, step = 24201 (22.312 sec)
# INFO:tensorflow:global_step/sec: 4.23819
# INFO:tensorflow:loss = 2692286.6432953654, step = 24301 (23.595 sec)
# INFO:tensorflow:global_step/sec: 3.48485
# INFO:tensorflow:loss = 2886623.748889908, step = 24401 (28.696 sec)
# INFO:tensorflow:global_step/sec: 3.62344
# INFO:tensorflow:loss = 3230129.6754263616, step = 24501 (27.598 sec)
# INFO:tensorflow:global_step/sec: 4.62484
# INFO:tensorflow:loss = 1618389.9911897038, step = 24601 (21.623 sec)
# INFO:tensorflow:global_step/sec: 3.81406
# INFO:tensorflow:loss = 4290520.45401161, step = 24701 (26.220 sec)
# INFO:tensorflow:global_step/sec: 4.20248
# INFO:tensorflow:loss = 2994701.995576701, step = 24801 (23.793 sec)
# INFO:tensorflow:global_step/sec: 3.91192
# INFO:tensorflow:loss = 2710588.8074055575, step = 24901 (25.563 sec)
# INFO:tensorflow:global_step/sec: 3.90753
# INFO:tensorflow:loss = 3889125.1245045457, step = 25001 (25.591 sec)
# INFO:tensorflow:global_step/sec: 3.67567
# INFO:tensorflow:loss = 2963739.371628208, step = 25101 (27.206 sec)
# INFO:tensorflow:global_step/sec: 3.57013
# INFO:tensorflow:loss = 2204760.926465979, step = 25201 (28.011 sec)
# INFO:tensorflow:global_step/sec: 4.3918
# INFO:tensorflow:loss = 5624726.800952252, step = 25301 (22.769 sec)
# INFO:tensorflow:global_step/sec: 4.44638
# INFO:tensorflow:loss = 4016777.3151076618, step = 25401 (22.490 sec)
# INFO:tensorflow:global_step/sec: 4.5181
# INFO:tensorflow:loss = 2793717.9382205014, step = 25501 (22.133 sec)
# INFO:tensorflow:Saving checkpoints for 25569 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.12433
# INFO:tensorflow:loss = 3491009.910194772, step = 25601 (24.246 sec)
# INFO:tensorflow:global_step/sec: 3.85428
# INFO:tensorflow:loss = 3202170.0167021407, step = 25701 (25.947 sec)
# INFO:tensorflow:global_step/sec: 3.67199
# INFO:tensorflow:loss = 998216.6260991733, step = 25801 (27.232 sec)
# INFO:tensorflow:global_step/sec: 3.78776
# INFO:tensorflow:loss = 2972376.98802491, step = 25901 (26.400 sec)
# INFO:tensorflow:global_step/sec: 4.01362
# INFO:tensorflow:loss = 2326325.5202887226, step = 26001 (24.917 sec)
# INFO:tensorflow:global_step/sec: 3.5041
# INFO:tensorflow:loss = 1132048.406457771, step = 26101 (28.537 sec)
# INFO:tensorflow:global_step/sec: 3.0996
# INFO:tensorflow:loss = 3566979.0462026447, step = 26201 (32.263 sec)
# INFO:tensorflow:global_step/sec: 3.78706
# INFO:tensorflow:loss = 617510.8349798245, step = 26301 (26.404 sec)
# INFO:tensorflow:global_step/sec: 4.47674
# INFO:tensorflow:loss = 1914828.4687533006, step = 26401 (22.338 sec)
# INFO:tensorflow:global_step/sec: 3.59159
# INFO:tensorflow:loss = 4516474.179081878, step = 26501 (27.846 sec)
# INFO:tensorflow:global_step/sec: 4.07685
# INFO:tensorflow:loss = 3131038.3301421264, step = 26601 (24.526 sec)
# INFO:tensorflow:global_step/sec: 3.78879
# INFO:tensorflow:loss = 1561001.8409439325, step = 26701 (26.393 sec)
# INFO:tensorflow:global_step/sec: 4.12391
# INFO:tensorflow:loss = 2109817.1706613814, step = 26801 (24.249 sec)
# INFO:tensorflow:global_step/sec: 3.91521
# INFO:tensorflow:loss = 1124225.2074794713, step = 26901 (25.541 sec)
# INFO:tensorflow:global_step/sec: 4.53104
# INFO:tensorflow:loss = 2375496.404252205, step = 27001 (22.070 sec)
# INFO:tensorflow:global_step/sec: 4.35417
# INFO:tensorflow:loss = 2317164.9606664805, step = 27101 (22.966 sec)
# INFO:tensorflow:global_step/sec: 3.84808
# INFO:tensorflow:loss = 2605318.3041945607, step = 27201 (25.988 sec)
# INFO:tensorflow:global_step/sec: 3.99322
# INFO:tensorflow:loss = 1338689.046084395, step = 27301 (25.046 sec)
# INFO:tensorflow:global_step/sec: 4.44106
# INFO:tensorflow:loss = 2399019.08401931, step = 27401 (22.514 sec)
# INFO:tensorflow:global_step/sec: 3.403
# INFO:tensorflow:loss = 1454162.679182222, step = 27501 (29.644 sec)
# INFO:tensorflow:global_step/sec: 3.36565
# INFO:tensorflow:loss = 1286269.2926415952, step = 27601 (29.454 sec)
# INFO:tensorflow:global_step/sec: 3.96039
# INFO:tensorflow:loss = 2183887.3233388704, step = 27701 (25.250 sec)
# INFO:tensorflow:global_step/sec: 3.67068
# INFO:tensorflow:loss = 2546895.323490033, step = 27801 (27.243 sec)
# INFO:tensorflow:Saving checkpoints for 27871 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.88382
# INFO:tensorflow:loss = 1140809.5631721774, step = 27901 (25.748 sec)
# INFO:tensorflow:global_step/sec: 4.25859
# INFO:tensorflow:loss = 1153121.0154463865, step = 28001 (23.483 sec)
# INFO:tensorflow:global_step/sec: 3.81525
# INFO:tensorflow:loss = 4642846.758827865, step = 28101 (26.210 sec)
# INFO:tensorflow:global_step/sec: 3.38392
# INFO:tensorflow:loss = 1647733.8525130914, step = 28201 (29.558 sec)
# INFO:tensorflow:global_step/sec: 2.97607
# INFO:tensorflow:loss = 3393304.217931336, step = 28301 (33.597 sec)
# INFO:tensorflow:global_step/sec: 3.994
# INFO:tensorflow:loss = 5156153.7810688475, step = 28401 (25.035 sec)
# INFO:tensorflow:global_step/sec: 3.64766
# INFO:tensorflow:loss = 3356807.306455069, step = 28501 (27.419 sec)
# INFO:tensorflow:global_step/sec: 3.33896
# INFO:tensorflow:loss = 2195047.8754952024, step = 28601 (29.948 sec)
# INFO:tensorflow:global_step/sec: 3.70044
# INFO:tensorflow:loss = 1476854.8872257378, step = 28701 (27.022 sec)
# INFO:tensorflow:global_step/sec: 4.42175
# INFO:tensorflow:loss = 981097.1426545212, step = 28801 (22.616 sec)
# INFO:tensorflow:global_step/sec: 4.09699
# INFO:tensorflow:loss = 814676.4519285181, step = 28901 (24.408 sec)
# INFO:tensorflow:global_step/sec: 4.22845
# INFO:tensorflow:loss = 2608955.857022923, step = 29001 (23.650 sec)
# INFO:tensorflow:global_step/sec: 4.37772
# INFO:tensorflow:loss = 2663378.3498398354, step = 29101 (22.843 sec)
# INFO:tensorflow:global_step/sec: 4.66072
# INFO:tensorflow:loss = 682997.8065809604, step = 29201 (21.456 sec)
# INFO:tensorflow:global_step/sec: 4.57856
# INFO:tensorflow:loss = 2420400.367247807, step = 29301 (21.841 sec)
# INFO:tensorflow:global_step/sec: 4.54712
# INFO:tensorflow:loss = 1371179.179428639, step = 29401 (21.992 sec)
# INFO:tensorflow:global_step/sec: 4.45095
# INFO:tensorflow:loss = 759161.6108873808, step = 29501 (22.467 sec)
# INFO:tensorflow:global_step/sec: 4.55412
# INFO:tensorflow:loss = 1100298.7902617343, step = 29601 (21.958 sec)
# INFO:tensorflow:global_step/sec: 4.55289
# INFO:tensorflow:loss = 1360418.4368283404, step = 29701 (21.964 sec)
# INFO:tensorflow:global_step/sec: 4.52445
# INFO:tensorflow:loss = 681231.9374848218, step = 29801 (22.102 sec)
# INFO:tensorflow:global_step/sec: 4.63511
# INFO:tensorflow:loss = 1661446.3646629779, step = 29901 (21.575 sec)
# INFO:tensorflow:global_step/sec: 4.7041
# INFO:tensorflow:loss = 1269368.455606606, step = 30001 (21.258 sec)
# INFO:tensorflow:global_step/sec: 4.6751
# INFO:tensorflow:loss = 1706050.6086312053, step = 30101 (21.390 sec)
# INFO:tensorflow:global_step/sec: 4.69724
# INFO:tensorflow:loss = 2902716.809038775, step = 30201 (21.289 sec)
# INFO:tensorflow:global_step/sec: 4.75066
# INFO:tensorflow:loss = 858411.038500464, step = 30301 (21.050 sec)
# INFO:tensorflow:Saving checkpoints for 30377 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.67389
# INFO:tensorflow:loss = 1280540.3254852644, step = 30401 (21.396 sec)
# INFO:tensorflow:global_step/sec: 4.71718
# INFO:tensorflow:loss = 1879146.684146045, step = 30501 (21.198 sec)
# INFO:tensorflow:global_step/sec: 4.57362
# INFO:tensorflow:loss = 593717.5633726384, step = 30601 (21.865 sec)
# INFO:tensorflow:global_step/sec: 4.66848
# INFO:tensorflow:loss = 1149776.068549072, step = 30701 (21.421 sec)
# INFO:tensorflow:global_step/sec: 4.54358
# INFO:tensorflow:loss = 1317093.3227552557, step = 30801 (22.010 sec)
# INFO:tensorflow:global_step/sec: 4.60545
# INFO:tensorflow:loss = 1148003.0875085043, step = 30901 (21.711 sec)
# INFO:tensorflow:global_step/sec: 4.68205
# INFO:tensorflow:loss = 1849648.3991739545, step = 31001 (21.361 sec)
# INFO:tensorflow:global_step/sec: 4.79608
# INFO:tensorflow:loss = 970045.1740025873, step = 31101 (20.850 sec)
# INFO:tensorflow:global_step/sec: 4.65954
# INFO:tensorflow:loss = 904934.2562727588, step = 31201 (21.460 sec)
# INFO:tensorflow:global_step/sec: 4.62625
# INFO:tensorflow:loss = 1105796.2369571747, step = 31301 (21.615 sec)
# INFO:tensorflow:global_step/sec: 4.53944
# INFO:tensorflow:loss = 1082835.8439047076, step = 31401 (22.029 sec)
# INFO:tensorflow:global_step/sec: 4.60012
# INFO:tensorflow:loss = 1120536.5165400251, step = 31501 (21.739 sec)
# INFO:tensorflow:global_step/sec: 4.60477
# INFO:tensorflow:loss = 964333.8111193007, step = 31601 (21.716 sec)
# INFO:tensorflow:global_step/sec: 4.55866
# INFO:tensorflow:loss = 1070163.029361946, step = 31701 (21.936 sec)
# INFO:tensorflow:global_step/sec: 4.55292
# INFO:tensorflow:loss = 741833.3670580362, step = 31801 (21.964 sec)
# INFO:tensorflow:global_step/sec: 4.6163
# INFO:tensorflow:loss = 780002.1382704903, step = 31901 (21.662 sec)
# INFO:tensorflow:global_step/sec: 4.63308
# INFO:tensorflow:loss = 642878.7083127617, step = 32001 (21.584 sec)
# INFO:tensorflow:global_step/sec: 4.70831
# INFO:tensorflow:loss = 2009647.268918494, step = 32101 (21.239 sec)
# INFO:tensorflow:global_step/sec: 4.64992
# INFO:tensorflow:loss = 740046.2371124618, step = 32201 (21.506 sec)
# INFO:tensorflow:global_step/sec: 4.65005
# INFO:tensorflow:loss = 652410.2983041175, step = 32301 (21.505 sec)
# INFO:tensorflow:global_step/sec: 4.72331
# INFO:tensorflow:loss = 796236.6686536418, step = 32401 (21.171 sec)
# INFO:tensorflow:global_step/sec: 4.59043
# INFO:tensorflow:loss = 669970.8608887122, step = 32501 (21.784 sec)
# INFO:tensorflow:global_step/sec: 4.59746
# INFO:tensorflow:loss = 902666.2769926095, step = 32601 (21.756 sec)
# INFO:tensorflow:global_step/sec: 4.57906
# INFO:tensorflow:loss = 1414034.6236432488, step = 32701 (21.834 sec)
# INFO:tensorflow:global_step/sec: 4.63582
# INFO:tensorflow:loss = 754865.0273357959, step = 32801 (21.571 sec)
# INFO:tensorflow:global_step/sec: 4.614
# INFO:tensorflow:loss = 743294.8917928322, step = 32901 (21.673 sec)
# INFO:tensorflow:global_step/sec: 4.66947
# INFO:tensorflow:loss = 1808078.4937243722, step = 33001 (21.416 sec)
# INFO:tensorflow:global_step/sec: 4.61566
# INFO:tensorflow:loss = 834511.1558689926, step = 33101 (21.666 sec)
# INFO:tensorflow:Saving checkpoints for 33155 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.59897
# INFO:tensorflow:loss = 346610.05461957824, step = 33201 (21.744 sec)
# INFO:tensorflow:global_step/sec: 4.57677
# INFO:tensorflow:loss = 800762.292978745, step = 33301 (21.849 sec)
# INFO:tensorflow:global_step/sec: 4.68357
# INFO:tensorflow:loss = 2174896.4919283623, step = 33401 (21.351 sec)
# INFO:tensorflow:global_step/sec: 4.65337
# INFO:tensorflow:loss = 435865.6743045574, step = 33501 (21.490 sec)
# INFO:tensorflow:global_step/sec: 4.48775
# INFO:tensorflow:loss = 1173786.5875580425, step = 33601 (22.283 sec)
# INFO:tensorflow:global_step/sec: 4.64262
# INFO:tensorflow:loss = 1984293.4655618472, step = 33701 (21.539 sec)
# INFO:tensorflow:global_step/sec: 4.67408
# INFO:tensorflow:loss = 620191.8229536416, step = 33801 (21.395 sec)
# INFO:tensorflow:global_step/sec: 4.67986
# INFO:tensorflow:loss = 702278.5806264565, step = 33901 (21.368 sec)
# INFO:tensorflow:global_step/sec: 4.68358
# INFO:tensorflow:loss = 740677.9230313452, step = 34001 (21.351 sec)
# INFO:tensorflow:global_step/sec: 4.66604
# INFO:tensorflow:loss = 245656.88091328234, step = 34101 (21.432 sec)
# INFO:tensorflow:global_step/sec: 4.66692
# INFO:tensorflow:loss = 705055.9854019053, step = 34201 (21.428 sec)
# INFO:tensorflow:global_step/sec: 4.61024
# INFO:tensorflow:loss = 2054878.0881139021, step = 34301 (21.691 sec)
# INFO:tensorflow:global_step/sec: 4.65042
# INFO:tensorflow:loss = 396623.99101894384, step = 34401 (21.503 sec)
# INFO:tensorflow:global_step/sec: 4.60115
# INFO:tensorflow:loss = 693347.1174378748, step = 34501 (21.734 sec)
# INFO:tensorflow:global_step/sec: 4.56107
# INFO:tensorflow:loss = 509797.9159090157, step = 34601 (21.924 sec)
# INFO:tensorflow:global_step/sec: 4.66074
# INFO:tensorflow:loss = 772157.4608919071, step = 34701 (21.456 sec)
# INFO:tensorflow:global_step/sec: 4.58962
# INFO:tensorflow:loss = 408937.5691836596, step = 34801 (21.788 sec)
# INFO:tensorflow:global_step/sec: 4.61981
# INFO:tensorflow:loss = 927536.6449445889, step = 34901 (21.646 sec)
# INFO:tensorflow:global_step/sec: 4.47714
# INFO:tensorflow:loss = 651714.7210423213, step = 35001 (22.335 sec)
# INFO:tensorflow:global_step/sec: 4.6627
# INFO:tensorflow:loss = 742256.2727708961, step = 35101 (21.447 sec)
# INFO:tensorflow:global_step/sec: 4.66151
# INFO:tensorflow:loss = 335992.73976746266, step = 35201 (21.452 sec)
# INFO:tensorflow:global_step/sec: 4.63057
# INFO:tensorflow:loss = 1202571.4416592545, step = 35301 (21.595 sec)
# INFO:tensorflow:global_step/sec: 4.67051
# INFO:tensorflow:loss = 5704070.312517007, step = 35401 (21.411 sec)
# INFO:tensorflow:global_step/sec: 4.7736
# INFO:tensorflow:loss = 1113319.225780097, step = 35501 (20.954 sec)
# INFO:tensorflow:global_step/sec: 4.57654
# INFO:tensorflow:loss = 851098.8572076116, step = 35601 (21.845 sec)
# INFO:tensorflow:global_step/sec: 4.71278
# INFO:tensorflow:loss = 1821612.8948199167, step = 35701 (21.219 sec)
# INFO:tensorflow:global_step/sec: 4.60044
# INFO:tensorflow:loss = 1832626.4969671862, step = 35801 (21.737 sec)
# INFO:tensorflow:global_step/sec: 4.63467
# INFO:tensorflow:loss = 2084844.4576866168, step = 35901 (21.577 sec)
# INFO:tensorflow:Saving checkpoints for 35935 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.66059
# INFO:tensorflow:loss = 825294.6583547059, step = 36001 (21.457 sec)
# INFO:tensorflow:global_step/sec: 4.59952
# INFO:tensorflow:loss = 1192631.7944655104, step = 36101 (21.741 sec)
# INFO:tensorflow:global_step/sec: 4.53713
# INFO:tensorflow:loss = 526655.112480223, step = 36201 (22.041 sec)
# INFO:tensorflow:global_step/sec: 4.52607
# INFO:tensorflow:loss = 1429311.5499446164, step = 36301 (22.094 sec)
# INFO:tensorflow:global_step/sec: 4.61135
# INFO:tensorflow:loss = 665120.5906262724, step = 36401 (21.686 sec)
# INFO:tensorflow:global_step/sec: 4.57875
# INFO:tensorflow:loss = 432820.7835214502, step = 36501 (21.840 sec)
# INFO:tensorflow:global_step/sec: 4.69818
# INFO:tensorflow:loss = 997091.6554707349, step = 36601 (21.285 sec)
# INFO:tensorflow:global_step/sec: 4.54811
# INFO:tensorflow:loss = 693162.866280966, step = 36701 (21.989 sec)
# INFO:tensorflow:global_step/sec: 4.55875
# INFO:tensorflow:loss = 548039.7463813815, step = 36801 (21.934 sec)
# INFO:tensorflow:global_step/sec: 4.59793
# INFO:tensorflow:loss = 569291.3823762918, step = 36901 (21.749 sec)
# INFO:tensorflow:global_step/sec: 4.51367
# INFO:tensorflow:loss = 423770.8973906709, step = 37001 (22.161 sec)
# INFO:tensorflow:global_step/sec: 4.6293
# INFO:tensorflow:loss = 538341.8537304888, step = 37101 (21.596 sec)
# INFO:tensorflow:global_step/sec: 4.74339
# INFO:tensorflow:loss = 485810.44924858154, step = 37201 (21.082 sec)
# INFO:tensorflow:global_step/sec: 4.66315
# INFO:tensorflow:loss = 377778.5987248663, step = 37301 (21.445 sec)
# INFO:tensorflow:global_step/sec: 4.65314
# INFO:tensorflow:loss = 472547.9051322865, step = 37401 (21.491 sec)
# INFO:tensorflow:global_step/sec: 4.70755
# INFO:tensorflow:loss = 1099210.4999712124, step = 37501 (21.242 sec)
# INFO:tensorflow:global_step/sec: 4.6943
# INFO:tensorflow:loss = 868062.1047222654, step = 37601 (21.303 sec)
# INFO:tensorflow:global_step/sec: 4.63906
# INFO:tensorflow:loss = 411415.2442004145, step = 37701 (21.555 sec)
# INFO:tensorflow:global_step/sec: 4.5135
# INFO:tensorflow:loss = 538478.5298702639, step = 37801 (22.156 sec)
# INFO:tensorflow:global_step/sec: 4.64513
# INFO:tensorflow:loss = 432930.7916438647, step = 37901 (21.528 sec)
# INFO:tensorflow:global_step/sec: 4.71354
# INFO:tensorflow:loss = 491310.08492769266, step = 38001 (21.216 sec)
# INFO:tensorflow:global_step/sec: 4.67885
# INFO:tensorflow:loss = 356912.5938121157, step = 38101 (21.373 sec)
# INFO:tensorflow:global_step/sec: 4.70534
# INFO:tensorflow:loss = 351856.2330177289, step = 38201 (21.254 sec)
# INFO:tensorflow:global_step/sec: 4.68785
# INFO:tensorflow:loss = 681624.1610656248, step = 38301 (21.330 sec)
# INFO:tensorflow:global_step/sec: 4.66131
# INFO:tensorflow:loss = 1217261.8410466218, step = 38401 (21.453 sec)
# INFO:tensorflow:global_step/sec: 4.69867
# INFO:tensorflow:loss = 761174.6327259929, step = 38501 (21.283 sec)
# INFO:tensorflow:global_step/sec: 4.68768
# INFO:tensorflow:loss = 434919.337069978, step = 38601 (21.332 sec)
# INFO:tensorflow:global_step/sec: 4.65238
# INFO:tensorflow:loss = 552354.3560724085, step = 38701 (21.495 sec)
# INFO:tensorflow:Saving checkpoints for 38715 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.62387
# INFO:tensorflow:loss = 506771.7220834512, step = 38801 (21.626 sec)
# INFO:tensorflow:global_step/sec: 4.63409
# INFO:tensorflow:loss = 837544.8761096478, step = 38901 (21.579 sec)
# INFO:tensorflow:global_step/sec: 4.58617
# INFO:tensorflow:loss = 258617.07179146935, step = 39001 (21.809 sec)
# INFO:tensorflow:global_step/sec: 4.54512
# INFO:tensorflow:loss = 709581.4099222032, step = 39101 (21.997 sec)
# INFO:tensorflow:global_step/sec: 4.62875
# INFO:tensorflow:loss = 172309.3087309132, step = 39201 (21.607 sec)
# INFO:tensorflow:global_step/sec: 3.60137
# INFO:tensorflow:loss = 528425.7180645686, step = 39301 (27.764 sec)
# INFO:tensorflow:global_step/sec: 4.24187
# INFO:tensorflow:loss = 789935.9440555805, step = 39401 (23.577 sec)
# INFO:tensorflow:global_step/sec: 4.27597
# INFO:tensorflow:loss = 842744.679834985, step = 39501 (23.384 sec)
# INFO:tensorflow:global_step/sec: 4.64845
# INFO:tensorflow:loss = 409687.5153894328, step = 39601 (21.513 sec)
# INFO:tensorflow:global_step/sec: 4.95399
# INFO:tensorflow:loss = 478963.16851487657, step = 39701 (20.191 sec)
# INFO:tensorflow:global_step/sec: 4.79641
# INFO:tensorflow:loss = 911789.9071197553, step = 39801 (20.844 sec)
# INFO:tensorflow:global_step/sec: 4.78993
# INFO:tensorflow:loss = 536700.1654195876, step = 39901 (20.877 sec)
# INFO:tensorflow:global_step/sec: 5.00468
# INFO:tensorflow:loss = 559169.1109296273, step = 40001 (19.981 sec)
# INFO:tensorflow:global_step/sec: 4.97852
# INFO:tensorflow:loss = 528403.6091720603, step = 40101 (20.086 sec)
# INFO:tensorflow:global_step/sec: 5.01748
# INFO:tensorflow:loss = 521705.33454561257, step = 40201 (19.930 sec)
# INFO:tensorflow:global_step/sec: 4.86832
# INFO:tensorflow:loss = 270357.6581160305, step = 40301 (20.541 sec)
# INFO:tensorflow:global_step/sec: 4.92628
# INFO:tensorflow:loss = 916308.19937216, step = 40401 (20.299 sec)
# INFO:tensorflow:global_step/sec: 4.79316
# INFO:tensorflow:loss = 257848.4183909622, step = 40501 (20.863 sec)
# INFO:tensorflow:global_step/sec: 5.02456
# INFO:tensorflow:loss = 358139.0543158771, step = 40601 (19.902 sec)
# INFO:tensorflow:global_step/sec: 4.69449
# INFO:tensorflow:loss = 1252868.8332984662, step = 40701 (21.301 sec)
# INFO:tensorflow:global_step/sec: 4.81105
# INFO:tensorflow:loss = 236167.48526749064, step = 40801 (20.786 sec)
# INFO:tensorflow:global_step/sec: 4.64165
# INFO:tensorflow:loss = 330486.9192880545, step = 40901 (21.544 sec)
# INFO:tensorflow:global_step/sec: 3.78507
# INFO:tensorflow:loss = 433981.1646513851, step = 41001 (26.420 sec)
# INFO:tensorflow:global_step/sec: 3.81394
# INFO:tensorflow:loss = 377351.4507199533, step = 41101 (26.220 sec)
# INFO:tensorflow:global_step/sec: 3.2745
# INFO:tensorflow:loss = 331513.00077424536, step = 41201 (30.538 sec)
# INFO:tensorflow:global_step/sec: 3.43165
# INFO:tensorflow:loss = 948841.9780868606, step = 41301 (29.142 sec)
# INFO:tensorflow:Saving checkpoints for 41359 into /tmp/tmpqhajrxkz/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.21713
# INFO:tensorflow:loss = 661165.4331099456, step = 41401 (31.084 sec)
# INFO:tensorflow:global_step/sec: 3.44863
# INFO:tensorflow:loss = 299916.9349828169, step = 41501 (28.996 sec)
# INFO:tensorflow:global_step/sec: 3.54992
# INFO:tensorflow:loss = 797689.1400792326, step = 41601 (28.170 sec)
# INFO:tensorflow:global_step/sec: 3.33825
# INFO:tensorflow:loss = 908585.662298799, step = 41701 (29.956 sec)
# INFO:tensorflow:global_step/sec: 3.42336
# INFO:tensorflow:loss = 369522.28039594373, step = 41801 (29.211 sec)
# INFO:tensorflow:global_step/sec: 3.5194
# INFO:tensorflow:loss = 310552.3986088708, step = 41901 (28.415 sec)
# INFO:tensorflow:global_step/sec: 3.25928
# INFO:tensorflow:loss = 280843.0154158173, step = 42001 (30.681 sec)
# INFO:tensorflow:global_step/sec: 3.61983
# INFO:tensorflow:loss = 277627.43394633906, step = 42101 (27.625 sec)
# INFO:tensorflow:global_step/sec: 3.43217
# INFO:tensorflow:loss = 251189.66358109054, step = 42201 (29.136 sec)
# INFO:tensorflow:global_step/sec: 3.48498
# INFO:tensorflow:loss = 593133.0223317458, step = 42301 (28.695 sec)
# INFO:tensorflow:global_step/sec: 3.48168
# INFO:tensorflow:loss = 294899.49963213055, step = 42401 (28.722 sec)
# INFO:tensorflow:global_step/sec: 3.39745
# INFO:tensorflow:loss = 164420.7696113232, step = 42501 (29.433 sec)
# INFO:tensorflow:global_step/sec: 3.38566
# INFO:tensorflow:loss = 310337.4241532611, step = 42601 (29.538 sec)
# INFO:tensorflow:global_step/sec: 3.31343
# INFO:tensorflow:loss = 423365.32837182353, step = 42701 (30.178 sec)
# INFO:tensorflow:global_step/sec: 3.30745
# INFO:tensorflow:loss = 265190.1399657935, step = 42801 (30.235 sec)
# INFO:tensorflow:global_step/sec: 3.14079
# INFO:tensorflow:loss = 303247.7108305587, step = 42901 (31.838 sec)
# INFO:tensorflow:global_step/sec: 3.52049
# INFO:tensorflow:loss = 331785.77305787744, step = 43001 (28.405 sec)
# INFO:tensorflow:global_step/sec: 3.79451
# INFO:tensorflow:loss = 342373.06575279677, step = 43101 (26.355 sec)
# INFO:tensorflow:global_step/sec: 3.74008
# INFO:tensorflow:loss = 231248.30817543436, step = 43201 (26.737 sec)
# INFO:tensorflow:global_step/sec: 3.5887
# INFO:tensorflow:loss = 312728.6998317128, step = 43301 (27.865 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d83da63cf691> in <module>()
# ----> 1 estimator.train(input_fn=input_fn)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     364
#     365       saving_listeners = _check_listeners_type(saving_listeners)
# --> 366       loss = self._train_model(input_fn, hooks, saving_listeners)
#     367       logging.info('Loss for final step: %s.', loss)
#     368       return self
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1117       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1118     else:
# -> 1119       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1120
#    1121   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1133       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1134                                              hooks, global_step_tensor,
# -> 1135                                              saving_listeners)
#    1136
#    1137   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1334       loss = None
#    1335       while not mon_sess.should_stop():
# -> 1336         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1337     return loss
#    1338
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     575                           feed_dict=feed_dict,
#     576                           options=options,
# --> 577                           run_metadata=run_metadata)
#     578
#     579   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1051                               feed_dict=feed_dict,
#    1052                               options=options,
# -> 1053                               run_metadata=run_metadata)
#    1054       except _PREEMPTION_ERRORS as e:
#    1055         logging.info('An error was raised. This may be due to a preemption in '
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1127   def run(self, *args, **kwargs):
#    1128     try:
# -> 1129       return self._sess.run(*args, **kwargs)
#    1130     except _PREEMPTION_ERRORS:
#    1131       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1199                                   feed_dict=feed_dict,
#    1200                                   options=options,
# -> 1201                                   run_metadata=run_metadata)
#    1202
#    1203     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     979
#     980   def run(self, *args, **kwargs):
# --> 981     return self._sess.run(*args, **kwargs)
#     982
#     983   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
d

# %%
createNum2WordDict(size=10,high=100000)
